# %%
# %run "/Workspace/Users/imsuryya@gmail.com/databricks/source_to_bronze/utils"

# %%
df3 = spark.read.format("delta").load("/Volumes/assingment/silver/emp/")

display(df3)

# %%
from pyspark.sql.functions import sum, col

Q1 = df3.groupBy("department") \
        .agg(sum("salary").alias("total_salary")) \
        .orderBy(col("total_salary").desc())

display(Q1)

# %%
avg_age_df = df.groupBy("department_name") \
               .agg(avg("age").alias("avg_age"))

display(avg_age_df)

# %%
df = read_delta("/Volumes/assingment/silver/emp/")
display(df)

# %%
avg_age_df = df.groupBy("department_name") \
               .agg(avg("age").alias("avg_age"))

display(avg_age_df)
